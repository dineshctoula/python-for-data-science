# %%
import numpy as np
# create a 2d array 
arr=np.array([[1,2,3],[4,5,6]])
# iterate using lat 
print("iterating using ")
for element in arr.flat:
    print(element)
# Out:
# iterating using
# 1
# 2
# 3
# 4
# 5
# 6
